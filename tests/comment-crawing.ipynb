# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/edu-data")
# !ls
# Out:
# video_with_channelcountry.csv  video_with_stem_titles_and_cutoff50.csv

# %%
import csv
import re

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
df_video = pd.read_csv('/content/drive/MyDrive/edu-data/video_with_stem_titles_and_cutoffs20.csv')

# %%
stem_videos = df_video[df_video["is_stem_cutoff_50"] == 1]

# %%
API_KEY = "YOUR-API-KEY"

# %%
import pandas as pd
from googleapiclient.discovery import build

youtube = build("youtube", "v3", developerKey=API_KEY)


def get_video_description(video_id):
    try:
        response = youtube.videos().list(part="snippet", id=video_id).execute()
        description = response["items"][0]["snippet"]["description"]
        return description
    except Exception as e:
        print(f"Error fetching description for video_id {video_id}: {e}")
        return None

stem_videos["description"] = stem_videos["display_id"].apply(get_video_description)
# Out:
# Error fetching description for video_id _GJX0DWITFQ: list index out of range
# Error fetching description for video_id jpvNdozKnw4: list index out of range
# Error fetching description for video_id ngcKEeVV-1E: list index out of range
# Error fetching description for video_id dshwPquv9kA: list index out of range
# Error fetching description for video_id 4h8Ll9_-SZY: list index out of range
# Error fetching description for video_id nJ31ZNpxTis: list index out of range
# Error fetching description for video_id CjjcglAnx68: list index out of range
# Error fetching description for video_id 4jROlXH9Nvc: list index out of range
# Error fetching description for video_id 3Dbxu-J4c5s: list index out of range
# Error fetching description for video_id gv1SEzJGeu4: list index out of range
# Error fetching description for video_id QzsbPQlVZak: list index out of range
# Error fetching description for video_id r1WsosD1ZsU: list index out of range
# ...

# %%
stem_videos['description'].iloc[5]
# Out:
# 'Mark, Erica, and Brian consider the HBO mini-series, plus "based on a true story" and why do we enjoy witnessing suffering?\r\n\r\n For more, visit prettymuchpop.com. Hear bonus content for this episode, and more episodes in advance, at patreon.com/prettymuchpop.\r\n\r\n This podcast is part of the Partially Examined Life podcast network and is curated by openculture.com.'

# %%
stem_videos.to_csv("stem_videos_cutoff20_descriptions.csv", index=False)

# %%
import pandas as pd
from googleapiclient.discovery import build
import csv

youtube = build("youtube", "v3", developerKey=API_KEY)

def get_top_level_comments(video_id, max_results=60):
    comments = []
    try:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=max_results
        )
        response = request.execute()

        for item in response.get("items", []):
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "display_id": video_id,
                "comment": snippet["textDisplay"],
                "comment_time": snippet["publishedAt"],
                "like_count": snippet["likeCount"]
            })
    except Exception as e:
        print(f"Error fetching comments for video_id {video_id}: {e}")
    return comments

test_videos = pd.DataFrame({
    "display_id": ["bE1Uq-sUFh8", "iflWc2x67uI"]
})

all_comments = []

for video_id in stem_videos["display_id"]:
    comments = get_top_level_comments(video_id, max_results=100)
    all_comments.extend(comments)

comments_df = pd.DataFrame(all_comments)

#print(comments_df)

#comments_df.to_csv("video_top_level_comments.csv", index=False)
# Out:
# Error fetching comments for video_id _GJX0DWITFQ: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_GJX0DWITFQ&maxResults=100&key=AIzaSyCvuOGIvyZshbSCwsDpZF0WQhuGKOixHhI&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# ...

# %%
comments_df.to_csv("stem_videos_cutoff50_comments.csv", index=False)
