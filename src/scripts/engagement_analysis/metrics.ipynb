# %% [markdown]
# # Task 3: Are Indian teachers good at STEM content? (Audience Engagement and Content Reception)
# ## Engagement Metrics Analysis: Look into the comments, likes, and dislikes to gauge audience reception.
# Analyze:
# * Whether Indian STEM videos have higher or lower engagement than non-STEM or non-Indian content.
# * Disaggregate likes, dislikes, and comments per video to assess the audience's interest in Indian educational content
#
# ## Sentiment Analysis / Text Analysis: What are the comments talking about? Are they discuss about the course content or just praising the content creator?
# Crawl some top comments of a sample of videos using Youtube API.
# Conduct sentiment analysis on comments to identify overall viewer attitudes. For deeper insights, categorize/cluster sentiments by themes or common terms to see what aspects of content resonate most. (e.g some topics have more negative sentiment than others?)
# Conducting Commenter (or channel) network analysis to see what kind of STEM videos are usually studied together (or made by a channel)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('stem_videos_final.csv')

# %%
len(df)
# Out:
# 74717

# %%
len(df['display_id'].unique())
# Out:
# 74531

# %%
result = df.sort_values(['display_id', 'crawl_date'], 
                          ascending=[True, False])\
              .drop_duplicates(subset=['display_id'], 
                             keep='first')\
              .reset_index(drop=True)

# %%
len(result)
# Out:
# 74531

# %%
result.head()
# Out:
#   categories                channel_id                  crawl_date  \
# 0  Education  UCW5YeuERMmlnqo4oq8vwUpg  2019-11-20 16:53:11.614086
# 1  Education  UCQv3dpUXUWvDFQarHrS5P9A  2019-11-23 03:22:07.204439
# 2  Education  UCF9IOB2TExg3QIBupFtBDxg  2019-11-23 11:10:27.240317
# 3  Education  UCh6KFtW4a4Ozr81GI1cxaBQ  2019-11-23 06:23:40.964312
# 4  Education  UCVt3U2ZvJiJMcO1FQtEp8TA  2019-11-04 22:10:58.727919
#
#    dislike_count   display_id  duration  like_count  \
# 0            3.0  ---_iWTjtB4       562       300.0
# 1            3.0  --5HmofySDA       162        20.0
# 2            0.0  --9445NFtDA       280         9.0
# 3            2.0  --FjuVSekrg      2602       101.0
# 4           43.0  --GLJISL-sM       292       291.0
#
#                                                 tags  \
# 0  python,python 3,python tutorial,python tutoria...
# 1  brian mclogan,free math videos,math,mathematic...
# 2         pressure sores,bed sores,decubitous ulcers
# 3        Type 1 diabetes,T1D,blood sugar,A1c,insulin
# 4  Regulation of glycolysis and gluconeogenesis,G...
#
#                                                title          upload_date  \
# 0       Python 3 Tutorial for Beginners #4 - Strings  2017-06-22 00:00:00
# 1  How to solve a two step inequality in two diff...  2014-07-21 00:00:00
# 2                Pressure sores 6, Sites on the body  2014-08-06 00:00:00
# 3                             Type 1 Diabetes Update  2019-04-13 00:00:00
# 4  Glycolysis vs Glycogenesis vs Glycogenolysis v...  2017-05-21 00:00:00
#
#    view_count                  name_cc  subscribers_cc country  is_stem_title  \
# 0     20865.0            The Net Ninja        329000.0      GB           True
# 1      1453.0            Brian McLogan        319000.0      US           True
# 2      1801.0        Dr. John Campbell        155000.0      GB           True
# 3      4392.0  University of Califo...        474000.0      US           True
# 4     17620.0  SWARNIM BIOLOGY CLAS...        492000.0      IN           True
#
#   title_matched_keywords  is_stem_tags  \
# 0        python, strings          True
# 1             inequality          True
# 2               pressure          True
# 3               diabetes          True
# 4             glycolysis          True
#
#                                     tag_matched_tags  \
# 0  python, python 3, python 3 string methods, pyt...
# 1  how to solve a two step inequality, how to sol...
# 2                                     pressure sores
# 3                                    Type 1 diabetes
# 4  Comparison between glycolysis and gluconeogene...
#
#                                 tag_matched_keywords
# 0                                    python, strings
# 1                           inequalities, inequality
# 2                                           pressure
# 3                                           diabetes
# 4  classes, glycolysis, metabolism, regulation, r...

# %%
result.to_csv('unique_stem_videos.csv', index=False)

# %%
import numpy as np

# Select 3% of th original data preserving country ratio
sample_size = int(len(df) * 0.03)
country_counts = result['country'].value_counts()
country_proportions = country_counts / len(result)
country_samples = (country_proportions * sample_size).round().astype(int)
diff = sample_size - country_samples.sum()
if diff != 0:
    # Add/subtract the difference from largest groups to minimize impact
    idx = country_samples.nlargest(abs(diff)).index
    for i in idx:
        country_samples[i] += np.sign(diff)

# Sample from each country
sampled_dfs = []
for country, n_samples in country_samples.items():
    if n_samples > 0:  # Skip if rounded to 0
        country_df = df[df['country'] == country]
        sampled_dfs.append(
            country_df.sample(n=min(n_samples, len(country_df)))
        )

# Combine samples
sample = pd.concat(sampled_dfs, ignore_index=True)

# Shuffle the final sample
sample = sample.sample(frac=1).reset_index(drop=True)
len(sample)
# Out:
# 2241

# %% [markdown]
# Let's add for each video:
# * commenters' nicknames
# * update on subscribers
# * update on likes and dislikes

# %%
sample.to_csv('sample_3perc.csv', index=False)

# %%
from googleapiclient.discovery import build

# API key
api_key = 'AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
print(response['items'][0]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
print(response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
# Out:
# @omarawad2251
# i think you forgot to multiple 2 with 13, idk if i am correct it feels like i forgot everything overnight

# %%
results = {}
fails = []
def callback(request_id: str, response: dict, exception: Exception = None):
        """Callback for video requests"""
        if exception is None:
            results[request_id] = response['items']
            comments = {}
            for item in response['items']:
                user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']
                comment = item['snippet']['topLevelComment']['snippet']['textOriginal']
                if user not in comments.keys():
                    comments[user] = []
                comments[user].append(comment)
            index = sample[sample['display_id'] == request_id].index
            sample.loc[sample['display_id'] == request_id, 'comments'] = json.dumps(comments)
    
        else:
            print(f"Error: {str(exception)}")
            fails.append(str(exception))

# %%
sample
# Out:
#      categories                channel_id                  crawl_date  \
# 0     Education  UCbYmF43dpGHz8gi2ugiXr0Q  2019-11-15 06:14:39.937759
# 1     Education  UCs_6DXZROU29pLvgQdCx4Ww  2019-11-23 03:55:12.306126
# 2     Education  UCUdgDNPGYCRJraG3BGxF2UA  2019-11-12 20:10:07.288370
# 3     Education  UCPiuJvuyMVFSwcIdBCTpTyQ  2019-11-17 02:22:29.026342
# 4     Education  UCfzlCWGWYyIQ0aLC5w48gBQ  2019-11-19 16:05:37.768167
# ...         ...                       ...                         ...
# 2236  Education  UC8xTHK97Ng__KZvGcO_K7CA  2019-11-04 18:22:29.684983
# 2237  Education  UCcv7pspGHmM7AOywuLM1ufA  2019-11-14 09:20:18.327951
# 2238  Education  UCEWpbFLzoYGPfuWUMFPSaoA  2019-11-15 07:28:40.452520
# 2239  Education  UCpzRDg0orQBZFBPzeXm1yNg  2019-11-16 14:49:14.370204
# 2240  Education  UCEWpbFLzoYGPfuWUMFPSaoA  2019-11-15 07:29:01.431263
#
#       dislike_count   display_id  duration  like_count  \
# 0               0.0  Ah2r7TCcE-U       491        40.0
# 1             126.0  LQtXu4k44Mo       335      5265.0
# 2               1.0  RThSYqEKAC4       127        14.0
# 3              66.0  NN2xMx-GlG8       373       774.0
# 4               5.0  g4y0x3dptMs       519       283.0
# ...             ...          ...       ...         ...
# 2236            3.0  bwJXuxJ0HRA       884       117.0
# 2237            0.0  l3wTHZxxU-g       134         3.0
# 2238           42.0  BqFVtlQa-2w      1058       469.0
# 2239            9.0  AkXhPsALJUw      1160       223.0
# 2240            7.0  DxX6XLEdcAw       841       237.0
#
#                                                    tags  \
# 0     Medicine,Exam Preparation,Medical Videos,Meduc...
# 1     Global Wealth Inequality - The TRUTH About The...
# 2     Dell,laptop,repair,tutorial,how-to,installatio...
# 3     Class 11 Physics,hooks law,dronstudy.com,IIT-J...
# 4     Kivy,Python (Programming Language),Mobile Appl...
# ...                                                 ...
# 2236  filterable gallery in html5,css3,jquery,filter...
# 2237  IIT JEE,jee advanced,IIT JEE Advanced,iit jee ...
# 2238  humidity,relative humidity,dew point,physics,v...
# 2239  PHP,Tutorial,Dreamweaver,Web,Site,Home,market,...
# 2240  equation of continuity physics,equation of con...
#
#                                                   title          upload_date  \
# 0     Airway Resistance:  Breathing and Lung Mechani...  2019-07-01 00:00:00
# 1     Global Wealth Inequality - The TRUTH About The 1%  2018-11-24 00:00:00
# 2     Dell Inspiron 11 (3147) CMOS Battery How-To Vi...  2014-12-02 00:00:00
# 3     Rigid Body - Mechanical Properties of Solids :...  2015-07-06 00:00:00
# 4     Kivy with Python tutorial Part 10 - Screen Man...  2015-02-26 00:00:00
# ...                                                 ...                  ...
# 2236  Filterable gallery with Html and JavaScript - ...  2017-12-24 00:00:00
# 2237  IIT JEE MATRICES If `A`\nis a non-singular mat...  2017-09-23 00:00:00
# 2238  Relative Humidity, Dew Point, Vapor & Partial ...  2016-12-01 00:00:00
# 2239  7. E - Commerce Website Tutorial - PHP MySQL D...  2011-01-03 00:00:00
# 2240  Continuity Equation, Volume Flow Rate & Mass F...  2017-11-15 00:00:00
#
#       view_count                  name_cc  subscribers_cc country  \
# 0         1588.0  Lecturio Medical Edu...        217745.0      US
# 1        81791.0                  Dan Lok       1900000.0      CA
# 2         3958.0  Parts-People.Com, In...         43600.0      US
# 3        80772.0            Dronstudy.com        914000.0      IN
# 4        44129.0                  sentdex        728000.0      US
# ...          ...                      ...             ...     ...
# 2236      5031.0        Online web ustaad         50500.0      US
# 2237       292.0                 Doubtnut        219000.0      IN
# 2238     64593.0  The Organic Chemistr...       1060000.0      US
# 2239     94011.0              Adam Khoury        189000.0      US
# 2240     31025.0  The Organic Chemistr...       1060000.0      US
#
#       is_stem_title title_matched_keywords  is_stem_tags  \
# 0              True             physiology          True
# 1              True             inequality          True
# 2              True                   cmos          True
# 3              True                physics          True
# 4              True                 python          True
# ...             ...                    ...           ...
# 2236           True             javascript          True
# 2237           True       matrices, matrix          True
# 2238           True      physics, pressure          True
# 2239           True                    php          True
# 2240           True    continuity, physics          True
#
#                                        tag_matched_tags  \
# 0                          Lungs Physiology, Physiology
# 1     Global Inequality, Global Wealth Inequality, G...
# 2                                          CMOS Battery
# 3       Class 11 Physics, Class XI Physics, IIT Physics
# 4     Mobile Application Development (Industry), Pyt...
# ...                                                 ...
# 2236                                         javascript
# 2237                         MATRICES, cengage learning
# 2238  partial pressure, physics, temperature, vapor ...
# 2239                                                PHP
# 2240  continuity equation, equation of continuity, e...
#
#                 tag_matched_keywords  \
# 0                         physiology
# 1                         inequality
# 2                               cmos
# 3                            physics
# 4                development, python
# ...                              ...
# 2236                      javascript
# 2237              learning, matrices
# 2238  physics, pressure, temperature
# 2239                             php
# 2240             continuity, physics
#
#                                                comments
# 0     {"@babygurll7": ["This helped me sooo much aft...
# 1     {"@successmindsxt": ["The future is entreprene...
# 2                                                    {}
# 3     {"@TopprStudy": ["\ud83d\udc49 \ud835\udc09\ud...
# 4     {"@franciscomartiarena": ["i've loved that 3d ...
# ...                                                 ...
# 2236                                                NaN
# 2237                                                NaN
# 2238                                                NaN
# 2239                                                NaN
# 2240                                                NaN
#
# [2241 rows x 20 columns]

# %%
batch_size = 50
for i in range(0, len(sample), batch_size):
    batch = youtube.new_batch_http_request()
    video_ids = sample['display_id'][i:i+batch_size]
    
    for id in video_ids:
        request = youtube.commentThreads().list(
            part='snippet',
            videoId=id,
            maxResults=100,
            order='relevance'
        )
        batch.add(request, callback=callback, request_id=id)
    batch.execute()
# Out:
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=4-R-AazB31U&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "One or more of the requested comment threads cannot be retrieved due to insufficient permissions. The request might not be properly authorized.". Details: "[{'message': 'One or more of the requested comment threads cannot be retrieved due to insufficient permissions. The request might not be properly authorized.', 'domain': 'youtube.commentThread', 'reason': 'forbidden', 'location': 'id', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SaQV4nOqG6M&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=sxmgMtNGlow&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=EPHmogxR-nk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=9oXMnCz2Ywo&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=p3xAoFw3AyM&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0de2nV8OHJk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=V1Mku9qi1y0&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=6Xb6IeQU1mQ&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=boFsvYAySo8&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=JCQpT8H24j4&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=aeZOVaULoNI&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=o60YJekI2OU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iPEv7Eebk9M&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Cz3OQVqWSOA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=GK8qPNZXrh0&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Yvbd92Pvi1I&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=pmI-r_-qvfA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iFJX3aj_LNA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=htwCnhMGVxA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=nmL7iTPYunE&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=2hduc-tHe0w&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=hAt2t_w7eCU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=f4E93p9txRc&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ltr-QZtmsow&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iVokMPWyyuA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=OVREC-WLEec&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=cMX7HJ9cMEE&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=4pKrHhXDd50&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=zrU902WLIOU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=QFbN1L35y14&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=KPBVdn4i4Lw&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ivJgfejDUvY&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=APBXfqVccS0&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=mGYUytLjJ8c&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=VviZzYw7bK8&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=KBcSKZ6Aoco&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=pPkP3DGED-I&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=j3lZe2OTBfQ&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=LYg5od5Rl-Y&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=TuFzbyHEpWc&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=EaRowyAq9o4&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=420Q450EqB0&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=9zgPKWS7Vpk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=unUKNBtQhtQ&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=RN7YG_HxZNQ&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=CD_Eh8GLCPA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iG1vobMDmxU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Jdw6WDauUH8&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Juy9AjXC3kM&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Am7J_Yy3BhM&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=AbOufTToViI&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=hcw9mNqNjHg&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=gVStbdDV6y8&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_SqLFAqGdvc&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=lSkUhtgOMNM&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=2oABjyoK2f8&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SW919MUrEkU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Eds6NfBI08o&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "One or more of the requested comment threads cannot be retrieved due to insufficient permissions. The request might not be properly authorized.". Details: "[{'message': 'One or more of the requested comment threads cannot be retrieved due to insufficient permissions. The request might not be properly authorized.', 'domain': 'youtube.commentThread', 'reason': 'forbidden', 'location': 'id', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=93gFDHSeGxY&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=jPkXpa_6EIU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=NMZ23bvps80&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=qmATVWWp9-Q&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bVfEb12T340&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=vj1afP-CEXk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=8ZU9_lw8Tvg&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=DAkjoA479-k&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=NQFtc4wKTBk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=wEIpB2dwgsc&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=uh2SirlQCHk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=lCoUUC5pQeQ&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=QDFpmrcoesM&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=4TT5iKt1nso&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=yEh2BTxbUSA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# ...
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=sBLuGj7pbq4&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=8CNtSAXoRIk&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=H90POEa1QVU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=5taEqqOkue4&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=vDMqwJLD4ac&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=W88f6QoN7po&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_qaMFG5M_pE&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=OjkUwrKrydA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=tpykIugYXbU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Omq7GUvdHkc&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0zyZJfKXdfQ&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YXyf-hG-10k&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=LX2q356N2rU&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ZcmO-7bUNEY&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=u9Qynzgu4og&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=rdWjlA3XsV0&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=XANO6u6EmcY&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=cs-A94P9Y1I&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=-HLaTmycpSs&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=4tBxAUkzyr4&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "One or more of the requested comment threads cannot be retrieved due to insufficient permissions. The request might not be properly authorized.". Details: "[{'message': 'One or more of the requested comment threads cannot be retrieved due to insufficient permissions. The request might not be properly authorized.', 'domain': 'youtube.commentThread', 'reason': 'forbidden', 'location': 'id', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=L1QHCuFvkj4&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=3YO0cTjHIOc&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=g3WhBaouKag&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bwJXuxJ0HRA&maxResults=100&order=relevance&key=AIzaSyDCEOWTrnZ1CSdm1AiE7Tw0xwEkV-oqwSc&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">

# %%
len(sample['comments'].unique())
# Out:
# 1722

# %%
len(fails)
# Out:
# 246

# %%
sample.to_csv('sample_with_comments.csv', index=False)

# %%
len(sample[sample['comments']=='{}'])
# Out:
# 263

# %%
len(sample['comments'].unique())+len(fails)+len(sample[sample['comments']=='{}'])
# Out:
# 2231
